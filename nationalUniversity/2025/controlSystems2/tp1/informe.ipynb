# %% [markdown]
# # Item 1: Modelo En Espacio De Estado Y Simulacion

# %% [markdown]
# Con las ecuaciones del modelo primero identificaron las entradas/salidas de interes y asignaron las variables de estado:
#
# ![image.png](attachment:image.png)
#
# Se plantearon las ecuaciones de estados y salida, y mediante octave se obtuvieron las matrices del modelo
#
# ![image-2.png](attachment:image-2.png)
#
# Se valuaron los parametros con los valores requeridos, obteniendo el modelo en espacio de estados:
#
# ![image-3.png](attachment:image-3.png)
#
# Utilizando la informacion del modelo obtenida con octave, se obtuvieron los parametros de simulacion
#
# ![image-4.png](attachment:image-4.png)
#
# * Paso De Tiempo: Relacionado Al 95% De La Exp Amortiguadora Mas Rapida (Polo Mas Alejado)
# * Tiempo De Sim, Relacionado Al 5% De La Exp Amortiguadora Mas Lenta (Polo Mas Cercano Al Origen)
#
# ![image-5.png](attachment:image-5.png)
#
# Finalmente se simulo el modelo:
#
# ![image-6.png](attachment:image-6.png)
